# %% [markdown]
# # Data Science I Topic 3.1 Descriptive Statistics

# %% [markdown]
# ## Non-programming Exercise

# %% [markdown]
# <u>In this non-programming exercise, please use the Code cells like you'd use your calculator during the exam (i.e. only standard arithmetic calculations up to whatever your scientific calculators can do).</u>

# %% [markdown]
# **Q1:** <u>Briefly (1-2 sentences), explain the differences of:</u>
#
# 1. Population vs. Sample
#
# 2. Parameter vs. Statistic
#
# 3. Variable vs. Constant
#
# 4. Qualitative vs. Quantitative Variables

# %% [markdown]
# <b>Ans</b>:
# 1. A sample is a representative subset of a population, because dealing with the total collection of elements (population) is simply unrealistic.
#
# 2. Parameter is a descriptive measure of a population, statistic is a descriptive measure of a sample.
#
# 3. Variable is a characterictic that can take on different values, whereas constant assumes the same value.
#
# 4. Qualitative variables consist of unordered or ordered (ranked) discrete categories, while quantitative variables are measurable in terms of numbers.

# %% [markdown]
# **Q2:** Given the following data of the lifetime (in hours) of 12 transistors:<br>
# 113, 121, 140, 106, 132, 134, 118, 117, 108, 122, 127, 138
# 1. Find the sample mean, median, variance, and standard deviation.
# 2. Assuming the lifetime of transistors follows a normal distribution, calculate the standard scores of the data points: 106, 117, 132, and 140.
# 3. We want to transform this dataset such that the mean is now 100 with variance of 10. Find the new transformed dataset.

# %% [markdown]
# **Ans**:
#
# The ordered data: <br>
# 106, 108, 113, 117, 118, 121, 122, 127, 132, 134, 138, 140<br>
#
# 1. Sample mean=123.0, median= 121.5, variance $ \approx 128.4 $, standard deviation $ \approx 11.3 $

# %%
# Sample mean
(106+108+113+117+118+121+122+127+132+134+138+140)/12
# Out:
# 123.0

# %% [markdown]
# median: 121.5

# %% [markdown]
# $\sum(X-\bar{X})^2$:

# %%
(106-123)**2+(108-123)**2+(113-123)**2+(117-123)**2+(118-123)**2+(121-123)**2+\
(122-123)**2+(127-123)**2+(132-123)**2+(134-123)**2+(138-123)**2+(140-123)**2
# Out:
# 1412

# %% [markdown]
# $S^2 = \sum(X-\bar{X})^2 / (n-1) $

# %%
# sample variance
print(1412/11)
# sample standard deviation
print((1412/11)**0.5)
# Out:
# 128.36363636363637
# 11.329767710047562

# %%
# Sanity check
import numpy as np
X=np.array([113, 121, 140, 106, 132, 134, 118, 117, 108, 122, 127, 138])
print(X.sum())
print(np.sort(X))
print(X.mean())
print(X.var(ddof=1))
print(X.std(ddof=1))
# Out:
# 1476
# [106 108 113 117 118 121 122 127 132 134 138 140]
# 123.0
# 128.36363636363637
# 11.329767710047562

# %% [markdown]
# 2. The standard scores of the data points: 106, 117, 132, and 140

# %%
print((106-123)/11.3)
print((117-123)/11.3)
print((132-123)/11.3)
print((140-123)/11.3)
# Out:
# -1.5044247787610618
# -0.5309734513274336
# 0.7964601769911503
# 1.5044247787610618

# %% [markdown]
# 3. The new transformed dataset

# %%
# 106, 108, 113, 117, 118, 121, 122, 127, 132, 134, 138, 140
print((106-123)/11.3 * 10**0.5 + 100)
print((108-123)/11.3 * 10**0.5 + 100)
print((113-123)/11.3 * 10**0.5 + 100)
print((117-123)/11.3 * 10**0.5 + 100)
print((118-123)/11.3 * 10**0.5 + 100)
print((121-123)/11.3 * 10**0.5 + 100)
print((122-123)/11.3 * 10**0.5 + 100)
print((127-123)/11.3 * 10**0.5 + 100)
print((132-123)/11.3 * 10**0.5 + 100)
print((134-123)/11.3 * 10**0.5 + 100)
print((138-123)/11.3 * 10**0.5 + 100)
print((140-123)/11.3 * 10**0.5 + 100)
# Out:
# 95.24259113072014
# 95.80228629181188
# 97.20152419454126
# 98.32091451672476
# 98.60076209727063
# 99.44030483890825
# 99.72015241945412
# 101.11939032218349
# 102.51862822491287
# 103.07832338600461
# 104.19771370818812
# 104.75740886927986

# %%
# sanity check
Xstd = np.array([95.24259113072014,
95.80228629181188,
97.20152419454126,
98.32091451672476,
98.60076209727063,
99.44030483890825,
99.72015241945412,
101.11939032218349,
102.51862822491287,
103.07832338600461,
104.19771370818812,
104.75740886927986])
print(Xstd.mean())
print(Xstd.var(ddof=1))
# Out:
# 100.0
# 10.05275560839817

# %% [markdown]
# **Q3**: <u>Describe the relationship of mean and median in:</u>
# * Normal distribution
# * Positively skewed distribution
# * Negatively skewed distribution

# %% [markdown]
# **Ans:**
# * normal dist: mean very close to median
# * positively skewed: mean>median
# * negatively skewed: mean<median

# %% [markdown]
# **Q4**: Calculate the Spearman and Pearson correlation coefficients between the **gold** and **total** medals achieved in the 2016 Olympic by the 12 countries shown below.
# <img src="attachment:medal.png" width="500">
# (source:Wiki)

# %% [markdown]
# **Ans**
# <img src="T3_1_Q4_1.png" width="500">

# %% [markdown]
# $$r_{GT}=\frac{\sum_{i=1}^{12}\left(G_{i}-\bar{G}\right)\left(T_{i}-\bar{T}\right)}{\sqrt{\sum_{i=1}^{12}\left(G_{i}-\bar{G}\right)^{2}}\sqrt{\sum_{j=1}^{12}\left(T_{j}-\bar{T}\right)^{2}}}=\frac{3710.5}{\sqrt{1485}\times\sqrt{9726.9}}\approx 0.98$$

# %%
3710.5/(1485*9726.9)**0.5
# Out:
# 0.976297064724331

# %% [markdown]
# <img src="T3_1_Q4_2.png" width="500">

# %% [markdown]
# $$\rho_{GT}=\frac{\sum_{i=1}^{12}\left(\textrm{rg}_{G,i}-\overline{\textrm{rg}}_{G}\right)\left(\textrm{rg}_{T,i}-\overline{\textrm{rg}}_{T}\right)}{\sqrt{\sum_{i=1}^{12}\left(\textrm{rg}_{G,i}-\overline{\textrm{rg}}_{G}\right)^{2}}\sqrt{\sum_{j=1}^{12}\left(\textrm{rg}_{T,j}-\overline{\textrm{rg}}_{T}\right)^{2}}}=\frac{130}{\sqrt{138}\times\sqrt{142.5}}\approx 0.93$$

# %%
130/(138*142.5)**0.5
# Out:
# 0.9270355246545425

# %%
import numpy as np
from scipy import stats
G = np.array([46,27,26,19,17,12,10,9,8,8,8,8])
T = np.array([121,67,70,56,42,41,42,21,28,29,19,15])
print(stats.pearsonr(G, T)[0])
print(stats.spearmanr(G, T)[0])
# Out:
# 0.9762962283017895
# 0.9270355246545426

# %% [markdown]
# ## Programming Exercise

# %% [markdown]
# <u>Descriptive statistics is concerned with the description and summarization of data. We need to present data in a meaningful way. We've seen before in T2 how to extract summary statistics and visual information from a data frame. In this tutorial we'll practise what we know from EDA and see more data description techniques.</u>

# %%
# !pip install pydataset

# %%
# Run this cell
from pydataset import data #if not installed, uncomment the previous cell and run it
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# For this tutorial, we are going to use the `birthwt` data set from `pydataset`. Follow the instructions below.

# %%
# Run this cell to show the dataset documentation
birthwt = data('birthwt', show_doc=True)
# Out:
# birthwt
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ##  Risk Factors Associated with Low Infant Birth Weight
#
# ### Description
#
# The `birthwt` data frame has 189 rows and 10 columns. The data were collected
# at Baystate Medical Center, Springfield, Mass during 1986.
#
# ### Usage
#
#     birthwt
#
# ### Format
#
# This data frame contains the following columns:
#
# `low`
#
# indicator of birth weight less than 2.5 kg.
#
# `age`
#
# mother's age in years.
#
# `lwt`
#
# mother's weight in pounds at last menstrual period.
#
# `race`
#
# mother's race (`1` = white, `2` = black, `3` = other).
#
# `smoke`
#
# smoking status during pregnancy.
#
# `ptl`
#
# number of previous premature labours.
#
# `ht`
#
# history of hypertension.
#
# `ui`
#
# presence of uterine irritability.
#
# `ftv`
#
# number of physician visits during the first trimester.
#
# `bwt`
#
# birth weight in grams.
#
# ### Source
#
# Hosmer, D.W. and Lemeshow, S. (1989) _Applied Logistic Regression._ New York:
# Wiley
#
# ### References
#
# Venables, W. N. and Ripley, B. D. (2002) _Modern Applied Statistics with S._
# Fourth edition. Springer.
#
# ### Examples
#
#     bwt <- with(birthwt, {
#     race <- factor(race, labels = c("white", "black", "other"))
#     ptd <- factor(ptl > 0)
#     ftv <- factor(ftv)
#     levels(ftv)[-(1:2)] <- "2+"
#     data.frame(low = factor(low), age, lwt, race, smoke = (smoke > 0),
#                ptd, ht = (ht > 0), ui = (ui > 0), ftv)
#     })
#     options(contrasts = c("contr.treatment", "contr.poly"))
#     glm(low ~ ., binomial, bwt)

# %%
# Run this cell to display the first 5 entries of birthwt
birthwt = data('birthwt')
print(birthwt.head())
# Out:
#     low  age  lwt  race  smoke  ptl  ht  ui  ftv   bwt
# 85    0   19  182     2      0    0   0   1    0  2523
# 86    0   33  155     3      0    0   0   0    3  2551
# 87    0   20  105     1      1    0   0   0    1  2557
# 88    0   21  108     1      1    0   0   1    2  2594
# 89    0   18  107     1      1    0   0   1    0  2600

# %%
# Optional: To see all available data from pydataset, run this cell.
pd.set_option("display.max_rows", None, "display.max_columns", None)
data()
# Out:
#                     dataset_id  \
# 0                AirPassengers
# 1                      BJsales
# 2                          BOD
# 3                 Formaldehyde
# 4                 HairEyeColor
# 5                 InsectSprays
# 6               JohnsonJohnson
# 7                    LakeHuron
# 8             LifeCycleSavings
# 9                         Nile
# 10               OrchardSprays
# 11                 PlantGrowth
# 12                   Puromycin
# 13                     Titanic
# 14                 ToothGrowth
# 15               UCBAdmissions
# 16              UKDriverDeaths
# 17                       UKgas
# 18                 USAccDeaths
# 19                   USArrests
# 20              USJudgeRatings
# 21       USPersonalExpenditure
# 22                    VADeaths
# 23                    WWWusage
# 24                 WorldPhones
# 25                    airmiles
# 26                  airquality
# 27                    anscombe
# 28                      attenu
# 29                    attitude
# 30                     austres
# 31                        cars
# 32                    chickwts
# 33                         co2
# 34                     crimtab
# 35                 discoveries
# 36                       esoph
# 37                        euro
# 38                    faithful
# 39                      freeny
# 40                      infert
# 41                        iris
# 42                     islands
# 43                          lh
# 44                     longley
# 45                        lynx
# 46                      morley
# 47                      mtcars
# 48                      nhtemp
# 49                      nottem
# 50                         npk
# 51          occupationalStatus
# 52                      precip
# 53                  presidents
# 54                    pressure
# 55                      quakes
# 56                       randu
# 57                      rivers
# 58                        rock
# 59                       sleep
# 60                   stackloss
# 61               sunspot.month
# 62                sunspot.year
# 63                    sunspots
# 64                       swiss
# 65                    treering
# 66                       trees
# 67                       uspop
# 68                     volcano
# 69                  warpbreaks
# 70                       women
# 71                        acme
# 72                        aids
# 73                   aircondit
# 74                  aircondit7
# 75                        amis
# 76                         aml
# 77                     bigcity
# 78                    brambles
# 79                     breslow
# 80                     calcium
# 81                        cane
# 82                  capability
# 83                       catsM
# 84                         cav
# 85                         cd4
# 86                    channing
# 87                        city
# 88                    claridge
# 89                       cloth
# 90                 co.transfer
# 91                        coal
# 92                      darwin
# 93                        dogs
# 94                    downs.bc
# 95                       ducks
# 96                         fir
# 97                       frets
# 98                        grav
# 99                     gravity
# 100                     hirose
# 101                      islay
# 102                     manaus
# 103                   melanoma
# 104                      motor
# 105                      neuro
# 106                   nitrofen
# 107                      nodal
# 108                    nuclear
# 109                    paulsen
# 110                    poisons
# 111                      polar
# 112                  remission
# 113                   salinity
# 114                   survival
# 115                        tau
# 116                       tuna
# 117                      urine
# 118                       wool
# 119                       aids
# 120                   alloauto
# 121                  allograft
# 122                        azt
# 123                     baboon
# 124                    bcdeter
# 125                      bfeed
# 126                        bmt
# 127                       bnct
# 128                     btrial
# 129                       burn
# 130                   channing
# 131                    drug6mp
# 132                    drughiv
# 133                       hodg
# 134                     kidney
# 135                  kidrecurr
# 136                    kidtran
# 137                     larynx
# 138                       lung
# 139                    pneumon
# 140                      psych
# 141                       rats
# 142                        std
# 143                    stddiag
# 144                     tongue
# 145                      twins
# 146                   Animals2
# 147                     CrohnD
# 148               NOxEmissions
# 149                  SiegelsEx
# 150                   aircraft
# 151                     airmay
# 152                    alcohol
# 153               ambientNOxCH
# 154                   bushfire
# 155                    carrots
# 156                      cloud
# 157                    coleman
# 158                    condroz
# 159                     cushny
# 160                   delivery
# 161                  education
# 162                   epilepsy
# 163                       exAM
# 164                  foodstamp
# 165                        hbk
# 166                      heart
# 167                   kootenay
# 168                     lactic
# 169                       milk
# 170                    pension
# 171                   phosphor
# 172                      pilot
# 173                  possumDiv
# 174                  pulpfiber
# 175                 radarImage
# 176                   salinity
# 177                   starsCYG
# 178                      telef
# 179                   toxicity
# 180                       vaso
# 181               wagnerGrowth
# 182                       wood
# 183                  AMSsurvey
# 184                      Adler
# 185                     Angell
# 186                   Anscombe
# 187                    Baumann
# 188                       Bfox
# 189                  Blackmoor
# 190                       Burt
# 191                     CanPop
# 192                      Chile
# 193                     Chirot
# 194                     Cowles
# 195                      Davis
# 196                  DavisThin
# 197               Depredations
# 198                     Duncan
# 199                   Ericksen
# 200                    Florida
# 201                   Freedman
# 202                   Friendly
# 203                   Ginzberg
# 204                     Greene
# 205                      Guyer
# 206                  Hartnagel
# 207                   Highway1
# 208                  Leinhardt
# 209                     Mandel
# 210                  Migration
# 211                      Moore
# 212                       Mroz
# 213               OBrienKaiser
# 214                   Ornstein
# 215                    Pottery
# 216                   Prestige
# 217                    Quartet
# 218                      Robey
# 219                       SLID
# 220                    Sahlins
# 221                   Salaries
# 222                      Soils
# 223                     States
# 224                   Transact
# 225                         UN
# 226                      USPop
# 227                      Vocab
# 228                 WeightLoss
# 229                    Womenlf
# 230                       Wool
# 231                agriculture
# 232                    animals
# 233                    chorSub
# 234                     flower
# 235                plantTraits
# 236                     pluton
# 237                    ruspini
# 238                votes.repub
# 239                     xclara
# 240                    affairs
# 241                 azcabgptca
# 242                   azdrg112
# 243                      azpro
# 244                azprocedure
# 245                  badhealth
# 246                  fasttrakg
# 247                    fishing
# 248                        lbw
# 249                     lbwgrp
# 250                     loomis
# 251                      mdvis
# 252                     medpar
# 253                       nuts
# 254                        rwm
# 255                    rwm1984
# 256                     rwm5yr
# 257                      ships
# 258                    smoking
# 259                    titanic
# 260                 titanicgrp
# 261                   Accident
# 262                    Airline
# 263                       Airq
# 264                   Benefits
# 265                       Bids
# 266                 BudgetFood
# 267                BudgetItaly
# 268                   BudgetUK
# 269                     Bwages
# 270                     CPSch3
# 271               CRANpackages
# 272                       Capm
# 273                        Car
# 274                   Caschool
# 275                     Catsup
# 276                      Cigar
# 277                  Cigarette
# 278                   Clothing
# 279                  Computers
# 280                    Cracker
# 281                      Crime
# 282                         DM
# 283                    Diamond
# 284                     Doctor
# 285                  DoctorAUS
# 286             DoctorContacts
# 287                   Earnings
# 288                Electricity
# 289                       Fair
# 290                   Fatality
# 291                    Fishing
# 292                    Forward
# 293                  FriendFoe
# 294                      Garch
# 295                   Gasoline
# 296                  Griliches
# 297                   Grunfeld
# 298                         HC
# 299                         HI
# 300                       Hdma
# 301                    Heating
# 302                    Hedonic
# 303                    Housing
# 304                   Icecream
# 305                   Journals
# 306                     Kakadu
# 307                    Ketchup
# 308                      Klein
# 309                LaborSupply
# 310                     Labour
# 311                       MCAS
# 312                      Males
# 313                  Mathlevel
# 314                     MedExp
# 315                      Metal
# 316                       Mode
# 317                 ModeChoice
# 318                       Mofa
# 319                       Mroz
# 320                     MunExp
# 321                NaturalPark
# 322                    Nerlove
# 323                        OFP
# 324                        Oil
# 325                       PSID
# 326              Participation
# 327                 PatentsHGH
# 328                  PatentsRD
# 329                      Pound
# 330                     Produc
# 331                  RetSchool
# 332                      SP500
# 333                  Schooling
# 334                 Somerville
# 335                       Star
# 336                     Strike
# 337                  StrikeDur
# 338                   StrikeNb
# 339                     SumHes
# 340                    Tobacco
# 341                      Train
# 342                   TranspEq
# 343                  Treatment
# 344                       Tuna
# 345          USFinanceIndustry
# 346      USclassifiedDocuments
# 347       USstateAbbreviations
# 348                 UStaxWords
# 349                   UnempDur
# 350               Unemployment
# 351                 University
# 352                   VietNamH
# 353                   VietNamI
# 354                      Wages
# 355                     Wages1
# 356               Workinghours
# 357                        Yen
# 358                     Yogurt
# 359              bankingCrises
# 360           incomeInequality
# 361            nonEnglishNames
# 362         politicalKnowledge
# 363                         PD
# 364                      aldh2
# 365                   apoeapoc
# 366                         cf
# 367                      crohn
# 368                         fa
# 369                      fsnps
# 370                        hla
# 371                     hr1420
# 372                        l51
# 373                      lukas
# 374                        mao
# 375                    mfblong
# 376                    mhtdata
# 377                     nep499
# 378                   diamonds
# 379                  economics
# 380                    midwest
# 381                     movies
# 382                        mpg
# 383                     msleep
# 384               presidential
# 385                      seals
# 386                  Arbuthnot
# 387                     Bowley
# 388                  Cavendish
# 389                 ChestSizes
# 390              CushnyPeebles
# 391             CushnyPeeblesN
# 392                     Dactyl
# 393                DrinksWages
# 394               Fingerprints
# 395                     Galton
# 396             GaltonFamilies
# 397                     Guerry
# 398                     Jevons
# 399                Langren.all
# 400                Langren1644
# 401                  Macdonell
# 402                MacdonellDF
# 403                  Michelson
# 404              MichelsonSets
# 405              Minard.cities
# 406                Minard.temp
# 407              Minard.troops
# 408                Nightingale
# 409                    OldMaps
# 410                 PearsonLee
# 411                PolioTrials
# 412                Prostitutes
# 413                        Pyx
# 414                   Quarrels
# 415                Snow.deaths
# 416              Snow.polygons
# 417                 Snow.pumps
# 418               Snow.streets
# 419                      Wheat
# 420             Wheat.monarchs
# 421                      Yeast
# 422                 YeastD.mat
# 423                    ZeaMays
# 424                     barley
# 425              environmental
# 426                    ethanol
# 427                   melanoma
# 428                     singer
# 429                      Aids2
# 430                    Animals
# 431                     Boston
# 432                     Cars93
# 433                   Cushings
# 434                        DDT
# 435                   GAGurine
# 436                  Insurance
# 437                   Melanoma
# 438                        OME
# 439                    Pima.te
# 440                    Pima.tr
# 441                   Pima.tr2
# 442                     Rabbit
# 443                     Rubber
# 444                      SP500
# 445                      Sitka
# 446                    Sitka89
# 447                       Skye
# 448                    Traffic
# 449                   UScereal
# 450                    UScrime
# 451                         VA
# 452                      abbey
# 453                  accdeaths
# 454                   anorexia
# 455                   bacteria
# 456                      beav1
# 457                      beav2
# 458                     biopsy
# 459                    birthwt
# 460                   cabbages
# 461                      caith
# 462                       cats
# 463                     cement
# 464                       chem
# 465                       coop
# 466                       cpus
# 467                      crabs
# 468                     deaths
# 469                    drivers
# 470                     eagles
# 471                       epil
# 472                      farms
# 473                        fgl
# 474                     forbes
# 475                   galaxies
# 476                      gehan
# 477                   genotype
# 478                     geyser
# 479                    gilgais
# 480                      hills
# 481                    housing
# 482                      immer
# 483                       leuk
# 484                    mammals
# 485                     mcycle
# 486                   menarche
# 487                  michelson
# 488                     minn38
# 489                     motors
# 490                     muscle
# 491                    newcomb
# 492                  nlschools
# 493                        npk
# 494                       npr1
# 495                       oats
# 496                   painters
# 497                     petrol
# 498                      quine
# 499                       road
# 500                    rotifer
# 501                      ships
# 502                     shrimp
# 503                    shuttle
# 504                     snails
# 505                      steam
# 506                    stormer
# 507                     survey
# 508                   synth.te
# 509                   synth.tr
# 510                       topo
# 511                     waders
# 512                  whiteside
# 513                     wtloss
# 514                      Cigar
# 515                      Crime
# 516                     EmplUK
# 517                   Gasoline
# 518                   Grunfeld
# 519                    Hedonic
# 520                LaborSupply
# 521                      Males
# 522                     Produc
# 523                     Snmesp
# 524                     SumHes
# 525                      Wages
# 526                   baseball
# 527  AustralianElectionPolling
# 528        AustralianElections
# 529                EfronMorris
# 530                RockTheVote
# 531           UKHouseOfCommons
# 532                   absentee
# 533                      admit
# 534                bioChemists
# 535                     ca2006
# 536                   iraqVote
# 537       politicalInformation
# 538      presidentialElections
# 539                   prussian
# 540               unionDensity
# 541                     vote92
# 542               french_fries
# 543                     smiths
# 544                       tips
# 545             car.test.frame
# 546                      car90
# 547                 cu.summary
# 548                   kyphosis
# 549                     solder
# 550                     stagec
# 551              PublicSchools
# 552                     Bollen
# 553                       CNES
# 554                      Klein
# 555                     Kmenta
# 556                      Tests
# 557                    bladder
# 558                     cancer
# 559                        cgd
# 560                      colon
# 561                    flchain
# 562                      heart
# 563                     kidney
# 564                   leukemia
# 565                      logan
# 566                       lung
# 567                       mgus
# 568                      nwtco
# 569                    ovarian
# 570                        pbc
# 571                       rats
# 572                  stanford2
# 573                      tobin
# 574                    veteran
# 575                  Arthritis
# 576                   Baseball
# 577             BrokenMarriage
# 578                 Bundesliga
# 579              Bundestag2005
# 580                  Butterfly
# 581                 CoalMiners
# 582              DanishWelfare
# 583                 Employment
# 584                 Federalist
# 585                    Hitters
# 586                 HorseKicks
# 587                   Hospital
# 588            JobSatisfaction
# 589                JointSports
# 590                  Lifeboats
# 591                NonResponse
# 592                OvaryCancer
# 593                     PreSex
# 594                 Punishment
# 595                    RepVict
# 596                     Saxony
# 597                  SexualFun
# 598               SpaceShuttle
# 599                    Suicide
# 600                     Trucks
# 601                   UKSoccer
# 602               VisualAcuity
# 603                    VonBort
# 604                 WeldonDice
# 605                 WomenQueue
# 606                MatchIt.url
# 607                     PErisk
# 608               SupremeCourt
# 609                     Weimar
# 610                  Zelig.url
# 611                   approval
# 612                  bivariate
# 613                  coalition
# 614                 coalition2
# 615                      eidat
# 616                      free1
# 617                      free2
# 618                 friendship
# 619                   grunfeld
# 620                       hoff
# 621                    homerun
# 622                      immi1
# 623                      immi2
# 624                      immi3
# 625                      immi4
# 626                      immi5
# 627                immigration
# 628                      klein
# 629                     kmenta
# 630                      macro
# 631                     mexico
# 632                        mid
# 633                newpainters
# 634                   sanction
# 635                     sna.ex
# 636                      swiss
# 637                      tobin
# 638                    turnout
# 639                 voteincome
# 640                        BCG
# 641                      BtheB
# 642                     CYGOB1
# 643                 Forbes2000
# 644                        GHQ
# 645                      Lanza
# 646                     agefat
# 647                    aspirin
# 648            birthdeathrates
# 649              bladdercancer
# 650                     clouds
# 651                   epilepsy
# 652                     foster
# 653                 heptathlon
# 654                 mastectomy
# 655                      meteo
# 656                orallesions
# 657                  phosphate
# 658                pistonrings
# 659                    planets
# 660                     plasma
# 661                     polyps
# 662                    polyps3
# 663                    pottery
# 664                  rearrests
# 665                respiratory
# 666                  roomwidth
# 667              schizophrenia
# 668             schizophrenia2
# 669                 schooldays
# 670                     skulls
# 671                    smoking
# 672                   students
# 673                   suicides
# 674                 toothpaste
# 675                     voting
# 676                      water
# 677                 watervoles
# 678                      waves
# 679                 weightgain
# 680                 womensrole
# 681                  Bechtoldt
# 682                Bechtoldt.1
# 683                Bechtoldt.2
# 684                      Dwyer
# 685                     Gleser
# 686                    Gorsuch
# 687                   Harman.5
# 688                   Harman.8
# 689           Harman.political
# 690                  Holzinger
# 691                Holzinger.9
# 692                      Reise
# 693                     Schmid
# 694                  Thurstone
# 695               Thurstone.33
# 696                     Tucker
# 697                    ability
# 698                     affect
# 699                        bfi
# 700             bfi.dictionary
# 701                       blot
# 702                       burt
# 703                     cities
# 704                     cubits
# 705                     cushny
# 706                        epi
# 707                    epi.bfi
# 708             epi.dictionary
# 709                     galton
# 710                    heights
# 711                     income
# 712                    iqitems
# 713                        msq
# 714                        neo
# 715                       peas
# 716                    sat.act
# 717              withinBetween
# 718                      Bosco
# 719                   CobarOre
# 720                    Mammals
# 721                      barro
# 722                      engel
# 723                        uis
# 724                     dietox
# 725                       koch
# 726                       ohio
# 727                    respdis
# 728                respiratory
# 729                    seizure
# 730                    sitka89
# 731                     spruce
# 732                      liver
# 733                  portpirie
# 734                       rain
# 735                     summer
# 736                  wavesurge
# 737                     winter
# 738                  arthritis
# 739                    housing
# 740                        bmw
# 741                     danish
# 742                nidd.annual
# 743                nidd.thresh
# 744                    siemens
# 745                     sp.raw
# 746                     spto87
# 747                   Dyestuff
# 748                  Dyestuff2
# 749                   InstEval
# 750                     Pastes
# 751                 Penicillin
# 752                    VerbAgg
# 753                       cake
# 754                       cbpp
# 755                grouseticks
# 756                 sleepstudy
#
#                                                                                          title
# 0                                                  Monthly Airline Passenger Numbers 1949-1960
# 1                                                            Sales Data with Leading Indicator
# 2                                                                    Biochemical Oxygen Demand
# 3                                                                Determination of Formaldehyde
# 4                                                    Hair and Eye Color of Statistics Students
# 5                                                               Effectiveness of Insect Sprays
# 6                                               Quarterly Earnings per Johnson & Johnson Share
# 7                                                                Level of Lake Huron 1875-1972
# 8                                                         Intercountry Life-Cycle Savings Data
# 9                                                                       Flow of the River Nile
# 10                                                                   Potency of Orchard Sprays
# 11                                                  Results from an Experiment on Plant Growth
# 12                                                  Reaction Velocity of an Enzymatic Reaction
# 13                                                       Survival of passengers on the Titanic
# 14                                      The Effect of Vitamin C on Tooth Growth in Guinea Pigs
# 15                                                           Student Admissions at UC Berkeley
# 16                                                    Road Casualties in Great Britain 1969-84
# 17                                                                UK Quarterly Gas Consumption
# 18                                                       Accidental Deaths in the US 1973-1978
# 19                                                             Violent Crime Rates by US State
# 20                                   Lawyers' Ratings of State Judges in the US Superior Court
# 21                                                                   Personal Expenditure Data
# 22                                                              Death Rates in Virginia (1940)
# 23                                                                   Internet Usage per Minute
# 24                                                                      The World's Telephones
# 25                                        Passenger Miles on Commercial US Airlines, 1937-1960
# 26                                                           New York Air Quality Measurements
# 27                                 Anscombe's Quartet of 'Identical' Simple Linear Regressions
# 28                                                           The Joyner-Boore Attenuation Data
# 29                                                          The Chatterjee-Price Attitude Data
# 30                                 Quarterly Time Series of the Number of Australian Residents
# 31                                                        Speed and Stopping Distances of Cars
# 32                                                                Chicken Weights by Feed Type
# 33                                                     Mauna Loa Atmospheric CO2 Concentration
# 34                                                               Student's 3000 Criminals Data
# 35                                                     Yearly Numbers of Important Discoveries
# 36                                                   Smoking, Alcohol and (O)esophageal Cancer
# 37                                                         Conversion Rates of Euro Currencies
# 38                                                                    Old Faithful Geyser Data
# 39                                                                       Freeny's Revenue Data
# 40                                          Infertility after Spontaneous and Induced Abortion
# 41                                                                  Edgar Anderson's Iris Data
# 42                                                       Areas of the World's Major Landmasses
# 43                                                        Luteinizing Hormone in Blood Samples
# 44                                                          Longley's Economic Regression Data
# 45                                                    Annual Canadian Lynx trappings 1821-1934
# 46                                                               Michelson Speed of Light Data
# 47                                                                  Motor Trend Car Road Tests
# 48                                                    Average Yearly Temperatures in New Haven
# 49                                       Average Monthly Temperatures at Nottingham, 1920-1939
# 50                                                      Classical N, P, K Factorial Experiment
# 51                                               Occupational Status of Fathers and their Sons
# 52                                                           Annual Precipitation in US Cities
# 53                                                 Quarterly Approval Ratings of US Presidents
# 54                                      Vapor Pressure of Mercury as a Function of Temperature
# 55                                                           Locations of Earthquakes off Fiji
# 56                                            Random Numbers from Congruential Generator RANDU
# 57                                                      Lengths of Major North American Rivers
# 58                                                      Measurements on Petroleum Rock Samples
# 59                                                                        Student's Sleep Data
# 60                                                            Brownlee's Stack Loss Plant Data
# 61                                                Monthly Sunspot Data, from 1749 to "Present"
# 62                                                              Yearly Sunspot Data, 1700-1988
# 63                                                          Monthly Sunspot Numbers, 1749-1983
# 64                                    Swiss Fertility and Socioeconomic Indicators (1888) Data
# 65                                                            Yearly Treering Data, -6000-1979
# 66                                             Girth, Height and Volume for Black Cherry Trees
# 67                                                       Populations Recorded by the US Census
# 68                                   Topographic Information on Auckland's Maunga Whau Volcano
# 69                                                 The Number of Breaks in Yarn during Weaving
# 70                                              Average Heights and Weights for American Women
# 71                                                                      Monthly Excess Returns
# 72                                                Delay in AIDS Reporting in England and Wales
# 73                                                      Failures of Air-conditioning Equipment
# 74                                                      Failures of Air-conditioning Equipment
# 75                                                              Car Speeding and Warning Signs
# 76                                             Remission Times for Acute Myelogenous Leukaemia
# 77                                                                   Population of U.S. Cities
# 78                                                           Spatial Location of Bramble Canes
# 79                                                                Smoking Deaths Among Doctors
# 80                                                                         Calcium Uptake Data
# 81                                                                     Sugar-cane Disease Data
# 82                                                        Simulated Manufacturing Process Data
# 83                                                               Weight Data for Domestic Cats
# 84                                                                 Position of Muscle Caveolae
# 85                                                        CD4 Counts for HIV-Positive Patients
# 86                                                                         Channing House Data
# 87                                                                   Population of U.S. Cities
# 88                                                            Genetic Links to Left-handedness
# 89                                                                    Number of Flaws in Cloth
# 90                                                                    Carbon Monoxide Transfer
# 91                                                              Dates of Coal Mining Disasters
# 92                                                           Darwin's Plant Height Differences
# 93                                                              Cardiac Data for Domestic Dogs
# 94                                            Incidence of Down's Syndrome in British Columbia
# 95                                      Behavioral and Plumage Characteristics of Hybrid Ducks
# 96                                                              Counts of Balsam-fir Seedlings
# 97                                                                 Head Dimensions in Brothers
# 98                                                                 Acceleration Due to Gravity
# 99                                                                 Acceleration Due to Gravity
# 100                                                                   Failure Time of PET Film
# 101                                                           Jura Quartzite Azimuths on Islay
# 102                                           Average Heights of the Rio Negro river at Manaus
# 103                                                           Survival from Malignant Melanoma
# 104                                                  Data from a Simulated Motorcycle Accident
# 105                                                      Neurophysiological Point Process Data
# 106                                                    Toxicity of Nitrofen in Aquatic Systems
# 107                                                       Nodal Involvement in Prostate Cancer
# 108                                                    Nuclear Power Station Construction Data
# 109                                                     Neurotransmission in Guinea Pig Brains
# 110                                                                      Animal Survival Times
# 111                                                 Pole Positions of New Caledonian Laterites
# 112                                                         Cancer Remission and Cell Activity
# 113                                                         Water Salinity and River Discharge
# 114                                                     Survival of Rats after Radiation Doses
# 115                                                                   Tau Particle Decay Modes
# 116                                                                         Tuna Sighting Data
# 117                                                                        Urine Analysis Data
# 118                                                            Australian Relative Wool Prices
# 119                                                                     data from Section 1.19
# 120                                                                      data from Section 1.9
# 121                                                              data from Exercise 13.1, p418
# 122                                                               data from Exercise 4.7, p122
# 123                                                               data from Exercise 5.8, p147
# 124                                                                     data from Section 1.18
# 125                                                                     data from Section 1.14
# 126                                                                      data from Section 1.3
# 127                                                               data from Exercise 7.7, p223
# 128                                                                      data from Section 1.5
# 129                                                                      data from Section 1.6
# 130                                                                     data from Section 1.16
# 131                                                                      data from Section 1.2
# 132                                                               data from Exercise 7.6, p222
# 133                                                                     data from Section 1.10
# 134                                                                      data from Section 1.4
# 135                                     Data on 38 individuals using a kidney dialysis machine
# 136                                                                      data from Section 1.7
# 137                                                                      data from Section 1.8
# 138                                                               data from Exercise 4.4, p120
# 139                                                                     data from Section 1.13
# 140                                                                     data from Section 1.15
# 141                                                              data from Exercise 7.13, p225
# 142                                                                     data from Section 1.12
# 143                                                               data from Exercise 5.6, p146
# 144                                                                     data from Section 1.11
# 145                                                              data from Exercise 7.14, p225
# 146                                      Brain and Body Weights for 65 Species of Land Animals
# 147                                                        Crohn's Disease Adverse Events Data
# 148                                                                     NOx Air Pollution Data
# 149                                                            Siegel's Exact Fit Example Data
# 150                                                                              Aircraft Data
# 151                                                                           Air Quality Data
# 152                                                           Alcohol Solubility in Water Data
# 153                                           Daily Means of NOx (mono-nitrogen oxides) in air
# 154                                                                     Campbell Bushfire Data
# 155                                                                  Insect Damages on Carrots
# 156                                                                    Cloud point of a Liquid
# 157                                                                           Coleman Data Set
# 158                                                                               Condroz Data
# 159                                              Cushny and Peebles Prolongation of Sleep Data
# 160                                                                         Delivery Time Data
# 161                                                                 Education Expenditure Data
# 162                                                                  Epilepsy Attacks Data Set
# 163                                    Example Data of Antille and May - for Simple Regression
# 164                                                           Food Stamp Program Participation
# 165                                                     Hawkins, Bradu, Kass's Artificial Data
# 166                                                                   Heart Catherization Data
# 167                              Waterflow Measurements of Kootenay River in Libby and Newgate
# 168                                                 Lactic Acid Concentration Measurement Data
# 169                                                             Daudin's Milk Composition Data
# 170                                                                         Pension Funds Data
# 171                                                                    Phosphorus Content Data
# 172                                                                           Pilot-Plant Data
# 173                                                                      Possum Diversity Data
# 174                                                                  Pulp Fiber and Paper Data
# 175                                                Satellite Radar Image Data from near Munich
# 176                                                                              Salinity Data
# 177                                   Hertzsprung-Russell Diagram Data of Star Cluster CYG OB1
# 178                                                 Number of International Calls from Belgium
# 179                                                          Toxicity of Carboxylic Acids Data
# 180                                                            Vaso Constriction Skin Data Set
# 181                                                   Wagner's Hannover Employment Growth Data
# 182                                                     Modified Data on Wood Specific Gravity
# 183                                                          American Math Society Survey Data
# 184                                                                  Experimenter Expectations
# 185                                                       Moral Integration of American Cities
# 186                                                     U. S. State Public-School Expenditures
# 187                                                  Methods of Teaching Reading Comprehension
# 188                                                Canadian Women's Labour-Force Participation
# 189                               Exercise Histories of Eating-Disordered and Control Subjects
# 190                                               Fraudulent Data on IQs of Twins Raised Apart
# 191                                                                   Canadian Population Data
# 192                                           Voting Intentions in the 1988 Chilean Plebiscite
# 193                                                        The 1907 Romanian Peasant Rebellion
# 194                                                    Cowles and Davis's Data on Volunteering
# 195                                                          Self-Reports of Height and Weight
# 196                                                         Davis's Data on Drive for Thinness
# 197                                                            Minnesota Wolf Depredation Data
# 198                                                        Duncan's Occupational Prestige Data
# 199                                                            The 1980 U.S. Census Undercount
# 200                                                                      Florida County Voting
# 201                                             Crowding and Crime in U. S. Metropolitan Areas
# 202                                                                   Format Effects on Recall
# 203                                                                         Data on Depression
# 204                                                                            Refugee Appeals
# 205                                                                  Anonymity and Cooperation
# 206                                                           Canadian Crime-Rates Time Series
# 207                                                                          Highway Accidents
# 208                                                                   Data on Infant-Mortality
# 209                                                                   Contrived Collinear Data
# 210                                                    Canadian Interprovincial Migration Data
# 211                                                   Status, Authoritarianism, and Conformity
# 212                                                     U.S. Women's Labor-Force Participation
# 213                                                O'Brien and Kaiser's Repeated-Measures Data
# 214                                       Interlocking Directorates Among Major Canadian Firms
# 215                                                            Chemical Composition of Pottery
# 216                                                           Prestige of Canadian Occupations
# 217                                                                   Four Regression Datasets
# 218                                                                Fertility and Contraception
# 219                                                       Survey of Labour and Income Dynamics
# 220                                                  Agricultural Production in Mazulu Village
# 221                                                                    Salaries for Professors
# 222                                 Soil Compositions of Physical and Chemical Characteristics
# 223                                       Education and Related Statistics for the U.S. States
# 224                                                                           Transaction data
# 225                                                                   GDP and Infant Mortality
# 226                                                            Population of the United States
# 227                                                                   Vocabulary and Education
# ...
# 593                                                                Pre-marital Sex and Divorce
# 594                                                                   Corporal Punishment Data
# 595                                                                  Repeat Victimization Data
# 596                                                                         Families in Saxony
# 597                                                                                 Sex is Fun
# 598                                                              Space Shuttle O-ring Failures
# 599                                                                   Suicide Rates in Germany
# 600                                                                       Truck Accidents Data
# 601                                                                           UK Soccer Scores
# 602                                                       Visual Acuity in Left and Right Eyes
# 603                                                           Von Bortkiewicz Horse Kicks Data
# 604                                                                         Weldon's Dice Data
# 605                                                                            Women in Queues
# 606                                                                   Table of links for Zelig
# 607                                     Political Economic Risk Data from 62 Countries in 1987
# 608                                                             U.S. Supreme Court Vote Matrix
# 609                                                                  1932 Weimar election data
# 610                                                                   Table of links for Zelig
# 611                                                            U.S. Presidential Approval Data
# 612                                                Sample data for bivariate probit regression
# 613                                         Coalition Dissolution in Parliamentary Democracies
# 614                       Coalition Dissolution in Parliamentary Democracies, Modified Version
# 615                                                   Simulation Data for Ecological Inference
# 616                                                                     Freedom of Speech Data
# 617                                                                     Freedom of Speech Data
# 618                                     Simulated Example of Schoolchildren Friendship Network
# 619  Simulation Data for model Seemingly Unrelated Regression (sur) that corresponds to met...
# 620                                                           Social Security Expenditure Data
# 621                       Sample Data on Home Runs Hit By Mark McGwire and Sammy Sosa in 1998.
# 622                                             Individual Preferences Over Immigration Policy
# 623                                             Individual Preferences Over Immigration Policy
# 624                                             Individual Preferences Over Immigration Policy
# 625                                             Individual Preferences Over Immigration Policy
# 626                                             Individual Preferences Over Immigration Policy
# 627                                             Individual Preferences Over Immigration Policy
# 628  Simulation Data for model Two-Stage Least Square (twosls) that corresponds to method 2...
# 629  Simulation Data for model Three-Stage Least Square (threesls) that corresponds to meth...
# 630                                                                         Macroeconomic Data
# 631                                     Voting Data from the 1988 Mexican Presidental Election
# 632                                                            Militarized Interstate Disputes
# 633                                                 The Discretized Painter's Data of de Piles
# 634                                                            Multilateral Economic Sanctions
# 635                                                   Simulated Example of Social Network Data
# 636                                   Swiss Fertility and Socioeconomic Indicators (1888) Data
# 637                                                                         Tobin's Tobit Data
# 638                                         Turnout Data Set from the National Election Survey
# 639                Sample Turnout and Demographic Data from the 2000 Current Population Survey
# 640                                                                           BCG Vaccine Data
# 641                                                                        Beat the Blues Data
# 642                                                                  CYG OB1 Star Cluster Data
# 643                       The Forbes 2000 Ranking of the World's Biggest Companies (Year 2004)
# 644                                                               General Health Questionnaire
# 645                                                      Prevention of Gastointestinal Damages
# 646                                                                Total Body Composision Data
# 647                                                                               Aspirin Data
# 648                                                                 Birth and Death Rates Data
# 649                                                                        Bladder Cancer Data
# 650                                                                         Cloud Seeding Data
# 651                                                                              Epilepsy Data
# 652                                                                  Foster Feeding Experiment
# 653                                                              Olympic Heptathlon Seoul 1988
# 654                                  Survival Times after Mastectomy of Breast Cancer Patients
# 655                                                   Meteorological Measurements for 11 Years
# 656                                                                Oral Lesions in Rural India
# 657                                                                       Phosphate Level Data
# 658                                                                      Piston Rings Failures
# 659                                                                            Exoplanets Data
# 660                                                                       Blood Screening Data
# 661                                                            Familial Andenomatous Polyposis
# 662                                                            Familial Andenomatous Polyposis
# 663                                                                Romano-British Pottery Data
# 664                                                               Rearrests of Juvenile Felons
# 665                                                                   Respiratory Illness Data
# 666                                                   Students Estimates of Lecture Room Width
# 667                                                         Age of Onset of Schizophrenia Data
# 668                                                                         Schizophrenia Data
# 669                                                                   Days not Spent at School
# 670                                                                            Egyptian Skulls
# 671                                                         Nicotine Gum and Smoking Cessation
# 672                                                                        Student Risk Taking
# 673                                                       Crowd Baiting Behaviour and Suicides
# 674                                                                            Toothpaste Data
# 675                                                       House of Representatives Voting Data
# 676                                                               Mortality and Water Hardness
# 677                                                                           Water Voles Data
# 678                                                         Electricity from Wave Power at Sea
# 679                                                                     Gain in Weight of Rats
# 680                                                                     Womens Role in Society
# 681                                               Seven data sets showing a bifactor solution.
# 682                                               Seven data sets showing a bifactor solution.
# 683                                               Seven data sets showing a bifactor solution.
# 684                                        8 cognitive variables used by Dwyer for an example.
# 685  Example data from Gleser, Cronbach and Rajaratnam (1965) to show basic principles of g...
# 686                      Example data set from Gorsuch (1997) for an example factor extension.
# 687                                              5 socio-economic variables from Harman (1967)
# 688                               Correlations of eight physical variables (from Harman, 1966)
# 689                            Eight political variables used by Harman (1967) as example 8.17
# 690                                               Seven data sets showing a bifactor solution.
# 691                                               Seven data sets showing a bifactor solution.
# 692                                               Seven data sets showing a bifactor solution.
# 693         12 variables created by Schmid and Leiman to show the Schmid-Leiman Transformation
# 694                                               Seven data sets showing a bifactor solution.
# 695                                               Seven data sets showing a bifactor solution.
# 696                                 9 Cognitive variables discussed by Tucker and Lewis (1973)
# 697                                           16 ability items scored as correct or incorrect.
# 698  Two data sets of affect and arousal scores as a function of personality and movie cond...
# 699                                                25 Personality items representing 5 factors
# 700                                                25 Personality items representing 5 factors
# 701                                                      Bond's Logical Operations Test - BLOT
# 702                                                    11 emotional variables from Burt (1915)
# 703                                                             Distances between 11 US cities
# 704          Galton's example of the relationship between height and 'cubit' or forearm length
# 705  A data set from Cushny and Peebles (1905) on the effect of three drugs on hours of sle...
# 706                             Eysenck Personality Inventory (EPI) data for 3570 participants
# 707           13 personality scales from the Eysenck Personality Inventory and Big 5 inventory
# 708                             Eysenck Personality Inventory (EPI) data for 3570 participants
# 709                                                      Galton's Mid parent child height data
# 710                               A data.frame of the Galton (1888) height and cubit data set.
# 711                                                       US family income from US census 2008
# 712                                                                16 multiple choice IQ items
# 713              75 mood items from the Motivational State Questionnaire for 3896 participants
# 714                                            NEO correlation matrix from the NEO_PI_R manual
# 715                                                                              Galton's Peas
# 716                                                     3 Measures of ability: SATV, SATQ, ACT
# 717          An example of the distinction between within group and between group correlations
# 718                                                                             Boscovich Data
# 719                                                                             Cobar Ore data
# 720                                             Garland(1983) Data on Running Speed of Mammals
# 721                                                                                 Barro Data
# 722                                                                                 Engel Data
# 723                                                              UIS Drug Treatment study data
# 724                                        Growth curves of pigs in a 3x3 factorial experiment
# 725                                                                     Ordinal Data from Koch
# 726                                                                Ohio Children Wheeze Status
# 727                                                     Clustered Ordinal Respiratory Disorder
# 728              Data from a clinical trial comparing two treatments for a respiratory illness
# 729                                                                         Epiliptic Seizures
# 730                                                               Growth of Sitka Spruce Trees
# 731                                                          Log-size of 79 Sitka spruce trees
# 732                                                              Liver related laboratory data
# 733                                                    Rain, wavesurge and portpirie datasets.
# 734                                                    Rain, wavesurge and portpirie datasets.
# 735                                Air pollution data, separately for summer and winter months
# 736                                                    Rain, wavesurge and portpirie datasets.
# 737                                Air pollution data, separately for summer and winter months
# 738                                                        Rheumatoid Arthritis Clinical Trial
# 739                                                                              Homeless Data
# 740                                                       Daily Log Returns on BMW Share Price
# 741                                                               Danish Fire Insurance Claims
# 742                                                                        The River Nidd Data
# 743                                                                        The River Nidd Data
# 744                                                   Daily Log Returns on Siemens Share Price
# 745                                                                       SP Data to June 1993
# 746                                                             SP Return Data to October 1987
# 747                                                                 Yield of dyestuff by batch
# 748                                                                 Yield of dyestuff by batch
# 749                               University Lecture/Instructor Evaluations by Students at ETH
# 750                                                           Paste strength by batch and cask
# 751                                                            Variation in penicillin testing
# 752                                                           Verbal Aggression item responses
# 753                                                          Breakage Angle of Chocolate Cakes
# 754                                                          Contagious bovine pleuropneumonia
# 755                                           Data on red grouse ticks from Elston et al. 2001
# 756                                                Reaction times in a sleep deprivation study

# %%
# If you run the cell directly above, also run this cell to reset the option
pd.reset_option('all', silent=True)

# %% [markdown]
# ## Describing data set

# %% [markdown]
# ### Reading a stem and leaf graph

# %% [markdown]
# <u>Run the following cell and answer the questions.</u>

# %%
#!pip install stemgraphic

# %%
import stemgraphic # may need to install first, uncomment and run the prev cell
stemgraphic.stem_graphic(birthwt.bwt)
plt.show()

# %% [markdown]
# <u>Note that the leaves are rounded off to the nearest tens (see the Key). Compare to the following list.</u>

# %%
# Run this cell to see the sorted values of all birth weights.
print(birthwt.bwt.sort_values().to_list())
# Out:
# [709, 1021, 1135, 1330, 1474, 1588, 1588, 1701, 1729, 1790, 1818, 1885, 1893, 1899, 1928, 1928, 1928, 1936, 1970, 2055, 2055, 2082, 2084, 2084, 2100, 2125, 2126, 2187, 2187, 2211, 2225, 2240, 2240, 2282, 2296, 2296, 2301, 2325, 2353, 2353, 2367, 2381, 2381, 2381, 2410, 2410, 2410, 2414, 2424, 2438, 2442, 2450, 2466, 2466, 2466, 2495, 2495, 2495, 2495, 2523, 2551, 2557, 2594, 2600, 2622, 2637, 2637, 2663, 2665, 2722, 2733, 2750, 2751, 2769, 2769, 2778, 2782, 2807, 2821, 2835, 2835, 2836, 2863, 2877, 2877, 2906, 2920, 2920, 2920, 2920, 2922, 2948, 2948, 2977, 2977, 2977, 2977, 3005, 3033, 3042, 3062, 3062, 3062, 3062, 3062, 3080, 3090, 3090, 3090, 3100, 3104, 3132, 3147, 3175, 3175, 3203, 3203, 3203, 3225, 3225, 3232, 3232, 3234, 3260, 3274, 3274, 3303, 3317, 3317, 3317, 3321, 3331, 3374, 3374, 3402, 3416, 3430, 3444, 3459, 3460, 3473, 3487, 3544, 3544, 3572, 3572, 3586, 3600, 3614, 3614, 3629, 3629, 3637, 3643, 3651, 3651, 3651, 3651, 3699, 3728, 3756, 3770, 3770, 3770, 3790, 3799, 3827, 3856, 3860, 3860, 3884, 3884, 3912, 3940, 3941, 3941, 3969, 3983, 3997, 3997, 4054, 4054, 4111, 4153, 4167, 4174, 4238, 4593, 4990]

# %% [markdown]
# <u>From the graph and rounded off to nearest tens of grams,</u>
#
# 1. What's the median weight?
# 2. How many babies were born with 3.2 kg birth weight?
# 3. How many babies were born with more than 4 kg? less than 1.5 kg?

# %% [markdown]
# **Ans:**
# * The median is underlined in the graph: 2980 grams.
# * 3 babies
# * 9 babies, 5 babies.

# %% [markdown]
# ***

# %% [markdown]
# ### Frequency tables using `pandas.crosstab()`

# %% [markdown]
# [Using `pandas.crosstab()`](https://pandas.pydata.org/docs/reference/api/pandas.crosstab.html)
#
# <u>Run the following cell and answer the questions by coding the calculations.</u>

# %%
# Recall low=1 when birth weight is <2.5kg (see the dataset description)
pd.crosstab(index=birthwt.age, # set index based on the age
            columns=[birthwt.low], # values to group by in the columns
            margins=True) # Add marginal value (row sums)
# Out:
# low    0   1  All
# age
# 14     1   2    3
# 15     1   2    3
# 16     6   1    7
# 17     7   5   12
# 18     8   2   10
# 19    13   3   16
# 20    10   8   18
# 21     7   5   12
# 22    11   2   13
# 23     8   5   13
# 24     8   5   13
# 25     9   6   15
# 26     4   4    8
# 27     1   2    3
# 28     7   2    9
# 29     6   1    7
# 30     6   1    7
# 31     4   1    5
# 32     5   1    6
# 33     3   0    3
# 34     0   1    1
# 35     2   0    2
# 36     2   0    2
# 45     1   0    1
# All  130  59  189

# %% [markdown]
# 1. What is the ratio of babies born with low birth weight?
# 2. Among women younger than 18, what is the ratio of babies born with low birth weight?

# %% [markdown]
# **Ans:**

# %%
# 1
print(59/189) # by reading the table
# OR
print(len(birthwt[birthwt.low==1]) / len(birthwt))
# Out:
# 0.31216931216931215
# 0.31216931216931215

# %%
# 2
print((2+2+1+5)/(3+3+7+12)) # by reading the table
# OR
print(len(birthwt[(birthwt.low==1) & (birthwt.age<18)]) / len(birthwt[birthwt.age<18]))
# Out:
# 0.4
# 0.4

# %% [markdown]
# <u>We can also set multiple column levels to group the values.</u>

# %%
# Try it: complete the following to get multiple column levels
pd.crosstab(index=birthwt.race, #set index based on the race
            columns=[birthwt.smoke, birthwt.low], # tabulate based on two column levels 
            margins=True) # display row sums
# Out:
# smoke   0       1      All
# low     0   1   0   1
# race
# 1      40   4  33  19   96
# 2      11   5   4   6   26
# 3      35  20   7   5   67
# All    86  29  44  30  189

# %% [markdown]
# ***
# * Among smokers, what's the ratio of babies with low birth weight?
# * Among non-smokers, what's the ratio of babies with low birth weight?

# %% [markdown]
# **Ans:**

# %%
30/(30+44)
# Out:
# 0.40540540540540543

# %%
29/(86+29)
# Out:
# 0.25217391304347825

# %% [markdown]
# ### Class Intervals

# %% [markdown]
# <u>We can reduce the data by grouping several actual scores into an interval of scores. It is suitable for a large dataset.</u>

# %%
birthwt.bwt.to_list()
# Out:
# [2523,
#  2551,
#  2557,
#  2594,
#  2600,
#  2622,
#  2637,
#  2637,
#  2663,
#  2665,
#  2722,
#  2733,
#  2751,
#  2750,
#  2769,
#  2769,
#  2778,
#  2782,
#  2807,
#  2821,
#  2835,
#  2835,
#  2836,
#  2863,
#  2877,
#  2877,
#  2906,
#  2920,
#  2920,
#  2920,
#  2920,
#  2948,
#  2948,
#  2977,
#  2977,
#  2977,
#  2977,
#  2922,
#  3005,
#  3033,
#  3042,
#  3062,
#  3062,
#  3062,
#  3062,
#  3062,
#  3080,
#  3090,
#  3090,
#  3090,
#  3100,
#  3104,
#  3132,
#  3147,
#  3175,
#  3175,
#  3203,
#  3203,
#  3203,
#  3225,
#  3225,
#  3232,
#  3232,
#  3234,
#  3260,
#  3274,
#  3274,
#  3303,
#  3317,
#  3317,
#  3317,
#  3321,
#  3331,
#  3374,
#  3374,
#  3402,
#  3416,
#  3430,
#  3444,
#  3459,
#  3460,
#  3473,
#  3544,
#  3487,
#  3544,
#  3572,
#  3572,
#  3586,
#  3600,
#  3614,
#  3614,
#  3629,
#  3629,
#  3637,
#  3643,
#  3651,
#  3651,
#  3651,
#  3651,
#  3699,
#  3728,
#  3756,
#  3770,
#  3770,
#  3770,
#  3790,
#  3799,
#  3827,
#  3856,
#  3860,
#  3860,
#  3884,
#  3884,
#  3912,
#  3940,
#  3941,
#  3941,
#  3969,
#  3983,
#  3997,
#  3997,
#  4054,
#  4054,
#  4111,
#  4153,
#  4167,
#  4174,
#  4238,
#  4593,
#  4990,
#  709,
#  1021,
#  1135,
#  1330,
#  1474,
#  1588,
#  1588,
#  1701,
#  1729,
#  1790,
#  1818,
#  1885,
#  1893,
#  1899,
#  1928,
#  1928,
#  1928,
#  1936,
#  1970,
#  2055,
#  2055,
#  2082,
#  2084,
#  2084,
#  2100,
#  2125,
#  2126,
#  2187,
#  2187,
#  2211,
#  2225,
#  2240,
#  2240,
#  2282,
#  2296,
#  2296,
#  2301,
#  2325,
#  2353,
#  2353,
#  2367,
#  2381,
#  2381,
#  2381,
#  2410,
#  2410,
#  2410,
#  2414,
#  2424,
#  2438,
#  2442,
#  2450,
#  2466,
#  2466,
#  2466,
#  2495,
#  2495,
#  2495,
#  2495]

# %%
# Run this cell
import numpy as np
bins = np.arange(1,6)*1000 #[1000,...,5000]

# add a new column to contain the interval groups
birthwt["wtint"] = np.digitize(birthwt.bwt.to_list(), 
                               bins, 
                               right=True) # right-inclusive
birthwt.head()
# Out:
#     low  age  lwt  race  smoke  ptl  ht  ui  ftv   bwt  wtint
# 85    0   19  182     2      0    0   0   1    0  2523      2
# 86    0   33  155     3      0    0   0   0    3  2551      2
# 87    0   20  105     1      1    0   0   0    1  2557      2
# 88    0   21  108     1      1    0   0   1    2  2594      2
# 89    0   18  107     1      1    0   0   1    0  2600      2

# %% [markdown]
# Weight interval groups (`wtint`) for baby weight at birth (`bwt`):
# * `wtint` = 0 : 0 < `bwt` $\leq$ 1000
# * `wtint` = 1 : 1000 < `bwt` $\leq$ 2000
# * `wtint` = 2 : 2000 < `bwt` $\leq$ 3000
# * `wtint` = 3 : 3000 < `bwt` $\leq$ 4000
# * `wtint` = 4 : 4000 < `bwt` $\leq$ 5000

# %% [markdown]
# <u>Using `.groupby()` and `.agg()`, display the mean, median, and count of the birth weights (`bwt`) per interval group.</u>

# %% [markdown]
# **Ans:**

# %%
birthwt.groupby("wtint").bwt.agg(['mean', 'median', 'count'])
# Out:
#               mean  median  count
# wtint
# 0       709.000000   709.0      1
# 1      1696.722222  1804.0     18
# 2      2546.910256  2495.0     78
# 3      3470.891566  3459.0     83
# 4      4281.555556  4167.0      9

# %%
birthwt.groupby("wtint").bwt.agg(['mean', 'median', pd.Series.mode])
# Out:
#               mean  median                mode
# wtint
# 0       709.000000   709.0                 709
# 1      1696.722222  1804.0                1928
# 2      2546.910256  2495.0  [2495, 2920, 2977]
# 3      3470.891566  3459.0                3062
# 4      4281.555556  4167.0                4054

# %% [markdown]
# ### Graphs

# %% [markdown]
# <u>We've seen some techniques in T2-EDA, so we won't see much more in this tutorial.</u>

# %% [markdown]
# <u>Display the histograms of birthweights to smokers/non-smokers in one plot.</u>

# %% [markdown]
# **Ans:**

# %%
birthwt.bwt[birthwt.smoke==0].hist(bins=20, alpha=0.8, color='b', label='non-smokers')
birthwt.bwt[birthwt.smoke==1].hist(bins=20, alpha=0.8, color='r', label='smokers')

plt.legend()
plt.xlabel('weight (grams)')
plt.show()

# %% [markdown]
# <u>You can get a normalized distribution plot by using `sns.displot`. Run the cell below and compare it to the histogram you've just created.</u>

# %%
# Try removing the argument hist=False to both distplot and see the difference

sns.distplot(birthwt.bwt[birthwt.smoke==0], bins=20, hist=False, color='b', label='non-smokers')
sns.distplot(birthwt.bwt[birthwt.smoke==1], bins=20, hist=False, color='r', label='smokers')

plt.show()
# Out:
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Summarizing data set

# %% [markdown]
# ### Percentile and Percentile Rank

# %% [markdown]
# <u>How do you interpret percentile, quantile, and percentile rank? Run the following cells. What do the numbers show?</u>

# %%
# with scipy.stats
from scipy import stats

stats.scoreatpercentile(birthwt.bwt,25)
# Out:
# 2414.0

# %%
# with numpy
np.percentile(birthwt.bwt,25)
# Out:
# 2414.0

# %%
# with pandas
birthwt.bwt.quantile(0.25)
# Out:
# 2414.0

# %% [markdown]
# <u>Complete the following to find the Interquartile Range (IQR)</u>

# %%
# with scipy.stats
Q1, Q3 = stats.scoreatpercentile(birthwt.bwt,25), stats.scoreatpercentile(birthwt.bwt,75)
print("Q1={}, Q3={}, IQR={}".format(Q1, Q3, Q3-Q1))
# Out:
# Q1=2414.0, Q3=3487.0, IQR=1073.0

# %%
Q3 = birthwt.bwt.quantile(0.75)
Q1 = birthwt.bwt.quantile(0.25)
Q3-Q1
# Out:
# 1073.0

# %%
# passes Pandas series to a lambda function
IQR = lambda x:x.quantile(0.75)-x.quantile(0.25)
IQR(birthwt.bwt)
# Out:
# 1073.0

# %%
# with scipy.stats
stats.iqr(birthwt.bwt)
# Out:
# 1073.0

# %% [markdown]
# **Ans:**
#
# It shows the number, in this case 2414, below which 25% of the data fall.

# %% [markdown]
# <u>What is the percentile rank of birth weight 2500 grams? How do you interprete this number?</u>

# %%
stats.percentileofscore(birthwt.bwt,2500)
# Out:
# 31.21693121693122

# %% [markdown]
# **Ans:**
#
# 2500 grams is on the 31th percentile, i.e. below 2500, fall 31% of the data.

# %% [markdown]
# ### Measure of Central Tendency

# %% [markdown]
# <u>Using `.groupby()` and `.agg()`, display the mean and median from :</u>
# * each weight interval
# * each race group
# * smokers/ non-smokers

# %% [markdown]
# **Ans:**

# %%
birthwt.groupby("wtint").bwt.agg(['mean', 'median'])
# Out:
#               mean  median
# wtint
# 0       709.000000   709.0
# 1      1696.722222  1804.0
# 2      2546.910256  2495.0
# 3      3470.891566  3459.0
# 4      4281.555556  4167.0

# %%
birthwt.groupby("wtint").bwt.agg(['mean', 'median', pd.Series.mode])
# Out:
#               mean  median                mode
# wtint
# 0       709.000000   709.0                 709
# 1      1696.722222  1804.0                1928
# 2      2546.910256  2495.0  [2495, 2920, 2977]
# 3      3470.891566  3459.0                3062
# 4      4281.555556  4167.0                4054

# %%
import scipy
birthwt.groupby("race").bwt.agg(['mean', 'median',lambda x: scipy.stats.mode(x)[0]])
# Out:
#              mean  median  <lambda_0>
# race
# 1     3102.718750  3062.0        3062
# 2     2719.692308  2849.0        2920
# 3     2805.283582  2835.0        3203

# %%
birthwt.groupby("smoke").bwt.agg(['mean', 'median'])
# Out:
#               mean  median
# smoke
# 0      3055.695652  3100.0
# 1      2771.918919  2775.5

# %% [markdown]
# ***
# <u>Describe the relationship of mean and median in:</u>
# * Normal distribution
# * Positively skewed distribution
# * Negatively skewed distribution

# %% [markdown]
# ### Box plots

# %%
# run this cell
sns.boxplot(y='bwt', data=birthwt)
plt.yticks(range(500,5001,500))
plt.grid(True)
plt.show()

# %% [markdown]
# ***
# #### Inter-quartile range

# %% [markdown]
# <u>From the boxplot, estimate:</u>
# * Min and max weights?
# * First quartile, Q1?
# * Third quartile, Q3?
# * Inter-quartile range, IQR?
#
# Compare your answers to the numbers obtained by using `pandas`/ `numpy`/ `stats`.

# %% [markdown]
# **Ans:**

# %% [markdown]
# * min$\approx1000$ (note the outlier at about 700 grams), max$\approx5000$ grams
# * Q1$\approx2400$
# * Q3$\approx3500$
# * IQR = Q3-Q1 = 1100

# %%
print('min:', birthwt.bwt.min(),'max:', birthwt.bwt.max())

Q1 = birthwt.bwt.quantile(0.25)
print("Q1=", Q1)

Q3 = birthwt.bwt.quantile(0.75)
print("Q3=", Q3)

IQR = Q3-Q1
print("IQR=", IQR)
# Out:
# min: 709 max: 4990
# Q1= 2414.0
# Q3= 3487.0
# IQR= 1073.0

# %% [markdown]
# #### Outliers identification

# %% [markdown]
# <u>Define RUB (reasonable upper boundary) to be RUB=Q3+1.5\*IQR and RLB (reasonable lower boundary) to be RLB=Q1-1.5\*IQR.<br>
# Find the outliers, which fall either below the RLB or above the RUB.</u>

# %% [markdown]
# **Ans:**

# %%
RUB = Q3+1.5*IQR
RLB = Q1-1.5*IQR

birthwt.bwt[(birthwt.bwt<RLB) | (birthwt.bwt>RUB)]
# Out:
# 4    709
# Name: bwt, dtype: int64

# %% [markdown]
# ### Measure of variation

# %% [markdown]
# #### Range

# %% [markdown]
# <u>The range of a set of data is the difference between the highest and lowest values in the set. <br>
# Display the range of the birth weights for:</u>
# * the whole set
# * grouped by smokers/ non-smokers

# %% [markdown]
# **Ans:**

# %%
# range of birthweight of the whole set
print('range = ', birthwt.bwt.max()-birthwt.bwt.min(), 'grams')
# Out:
# range =  4281 grams

# %%
print('grouped range:')
birthwt.groupby('smoke').bwt.max()-birthwt.groupby('smoke').bwt.min()
# Out:
# grouped range:
# smoke
# 0    3969
# 1    3529
# Name: bwt, dtype: int64

# %% [markdown]
# #### Deviation score

# %% [markdown]
# The difference between given score and the mean, $$x_{i}=\left(X_{i}-\bar{X}\right)$$

# %% [markdown]
# <u>Add a new column, `devscore`, that contains the deviation scores of birth weights, to `birthwt` DataFrame.</u>

# %% [markdown]
# **Ans:**

# %%
birthwt["devscore"] = birthwt.bwt - birthwt.bwt.mean()
birthwt.head(3)
# Out:
#     low  age  lwt  race  smoke  ptl  ht  ui  ftv   bwt  wtint    devscore
# 85    0   19  182     2      0    0   0   1    0  2523      2 -421.587302
# 86    0   33  155     3      0    0   0   0    3  2551      2 -393.587302
# 87    0   20  105     1      1    0   0   0    1  2557      2 -387.587302

# %% [markdown]
# #### Mean absolute deviation

# %% [markdown]
# The average of the absolute values of the deviation scores, $$\text{MAD}=\frac{\sum\left|X_{i}-\bar{X}\right|}{n}=\frac{\sum x_{i}}{n}$$

# %% [markdown]
# ***
# Display the mean deviation by either:
# * `.abs()` followed by `mean()` on `devscore`
# * `.mad()` on birthwt.bwt

# %% [markdown]
# **Ans:**

# %%
print('Mean deviation =', birthwt.devscore.abs().mean())
# Out:
# Mean deviation = 591.0311581422714

# %%
# skewness of birthweight
birthwt.bwt.mad()
# Out:
# 591.0311581422714

# %% [markdown]
# #### Variance and standard deviation

# %% [markdown]
# <u>Display the variance and standard deviation of the birth weights per weight interval `wtint`.</u>

# %%
birthwt.groupby('wtint').bwt.agg(['var', 'std'])
# Out:
#                 var         std
# wtint
# 0               NaN         NaN
# 1      83036.800654  288.161067
# 2      77972.576257  279.235700
# 3      89501.390538  299.167830
# 4      96832.277778  311.178852

# %% [markdown]
# ### Measure of Symmetry

# %% [markdown]
# #### Skewness

# %% [markdown]
# <u>Skewness is a measure of (the lack of) symmetry. You can use `.skew()` on pandas series.</u>
# * less than -1 or greater than +1: highly skewed.
# * between -1 and -0.5 or between +0.5 and +1: moderately skewed.
# * between -0.5 and 0.5: approximately symmetric.
# <br>
# <br>
# <u>Display the skewness of the whole birthweights. What can you conclude?</u>

# %% [markdown]
# **Ans:**

# %%
# skewness of birth weights
birthwt.bwt.skew()
# Out:
# -0.20863702335894543

# %% [markdown]
# approximately symmetric.

# %% [markdown]
# #### Kurtosis

# %% [markdown]
# <u>Kurtosis is a measure of whether the data are heavy-tailed or light-tailed relative to a normal distribution.</u>
# * excess kurtosis of a normal distribution: exactly 0
# * excess kurtosis<0 : platykurtic (shorter and thinner tails, central peak is lower and broader)
# * excess kurtosis>0 : leptokurtic (longer and fatter tails, central peak is higher and sharper)
# <br><br>
# <u>Using `.kurt()`, display the (excess) kurtosis of the whole birthweights. What can you conclude?</u>

# %% [markdown]
# **Ans:**

# %%
# the excess kurtosis of birth weight distribution
birthwt.bwt.kurt()
# Out:
# -0.08383885416863368

# %% [markdown]
# Very close to normal distribution because the excess kurtosis is very close to 0. The negative value indicates it slightly tends to be platykurtic.

# %%
sns.distplot(birthwt.bwt, bins=20)
plt.show()
# Out:
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# #### Standard scores

# %% [markdown]
# <u>A dataset is normal if its scores are clustered around its median (less data as you go farther from the median).<br>
# Empirical rules: if the dataset is normal then</u>
# * 68% of data lies within $\mu\pm s$
# * 95% of data lies within $\mu\pm 2s$
# * 99.7% of data lies within $\mu\pm 3s$
# <br>
# <u>When a dataset is normally distributed, we can find out the probability of a score occurring by standardising the scores.</u>

# %% [markdown]
# <u>Using `stats.percentileofscore()`, `.mean()`, and `.std`, check how many percents of the birth weights fall within $\mu\pm s$, $\mu\pm 2s$, and $\mu\pm 3s$. Close enough to approximate to normal distribution?</u>

# %% [markdown]
# **Ans:**

# %%
def perc_data(x,ns):
    """Return percentage of data contained in the interval mu +/- ns*sigma"""
    mu = x.mean()
    s = x.std()
    return stats.percentileofscore(birthwt.bwt, mu+ns*s)-stats.percentileofscore(birthwt.bwt, mu-ns*s)

# %%
# check +/- s
perc_data(birthwt.bwt, 1)
# Out:
# 67.72486772486772

# %%
#check +/-2s
perc_data(birthwt.bwt, 2)
# Out:
# 96.29629629629629

# %%
#check +/-3s
perc_data(birthwt.bwt, 3)
# Out:
# 99.47089947089947

# %% [markdown]
# Close enough to normal distribution.

# %% [markdown]
# #### Z-scores

# %% [markdown]
# <u>The Z-score, or standard score, is the number of standard deviations a given data point lies above or below mean, $$z=\frac{X-\bar{X}}{s},$$ where $s$ is the standard deviation.</u>

# %% [markdown]
# <u>Add a new column, `zscore`, to `birthwt` DataFrame.</u>
# <br><br>
# Hint: either use the formula and the familiar `.mean()` and `.std()` or find out how to use `stats.zscore()`.
# <br><br>
# Note that the default degree of freedom (d.o.f) for `stats.zscore` is $n$, while the standard deviation in `.std()` is based on d.o.f of $n-1$, so the numbers will be slightly different unless we set the d.o.f correction, ddof, to 1 (`ddof=1`).

# %% [markdown]
# **Ans:**

# %%
birthwt["zscore"] = (birthwt.bwt-birthwt.bwt.mean())/birthwt.bwt.std()

# %%
# alternative, use stats.zscore
# birthwt["zscore"] = stats.zscore(birthwt.bwt, ddof=1)

# %%
birthwt["zscore"]
# Out:
# 85   -0.578139
# 86   -0.539742
# 87   -0.531514
# 88   -0.480774
# 89   -0.472546
#         ...
# 79   -0.656305
# 81   -0.616537
# 82   -0.616537
# 83   -0.616537
# 84   -0.616537
# Name: zscore, Length: 189, dtype: float64

# %% [markdown]
# ### Transformed standard scores

# %% [markdown]
# Say we want to transform our standardized score $z$ into a distribution with a new mean $\bar{X}^{\prime}$ and standard deviation $s^{\prime}$, the transformed score is given by $$X^{\prime}=\left(s^{\prime}\right)\left(z\right)+\bar{X}^{\prime}$$

# %% [markdown]
# <u>Add a new column `trfwt` to contain the transformed data with new mean of 3000 grams and standard deviation of 500 grams. Check the new mean, median, and standard deviation.</u>

# %% [markdown]
# **Ans:**

# %%
birthwt["trfwt"] = 500*birthwt.zscore+3000
birthwt.head()
# Out:
#     low  age  lwt  race  smoke  ptl  ht  ui  ftv   bwt  wtint    devscore  \
# 85    0   19  182     2      0    0   0   1    0  2523      2 -421.587302
# 86    0   33  155     3      0    0   0   0    3  2551      2 -393.587302
# 87    0   20  105     1      1    0   0   0    1  2557      2 -387.587302
# 88    0   21  108     1      1    0   0   1    2  2594      2 -350.587302
# 89    0   18  107     1      1    0   0   1    0  2600      2 -344.587302
#
#       zscore        trfwt
# 85 -0.578139  2710.930446
# 86 -0.539742  2730.129192
# 87 -0.531514  2734.243209
# 88 -0.480774  2759.612981
# 89 -0.472546  2763.726998

# %%
birthwt.trfwt.agg(['mean', 'median', 'std'])
# Out:
# mean      3000.000000
# median    3022.224399
# std        500.000000
# Name: trfwt, dtype: float64

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# <u>Find the Pearson's r and Spearman's rho correlation coefficients between `age` and `bwt`</u>

# %%
#Pandas

# Pearson's r
print(birthwt[["age", "bwt"]].corr())

# Spearman's rho
print(birthwt[["age", "bwt"]].corr(method="spearman"))
# Out:
#           age       bwt
# age  1.000000  0.090318
# bwt  0.090318  1.000000
#           age       bwt
# age  1.000000  0.061234
# bwt  0.061234  1.000000

# %%
birthwt[["age", "bwt"]].corr().loc["age", "bwt"]
# Out:
# 0.0903178136685322

# %%
# scipy.stats
print(stats.pearsonr(birthwt.age, birthwt.bwt)[0])
print(stats.spearmanr(birthwt.age, birthwt.bwt)[0])
# Out:
# 0.09031781366853263
# 0.06123375649686542

# %%
# Numpy
np.corrcoef(birthwt.age, birthwt.bwt)
# Out:
# array([[1.        , 0.09031781],
#        [0.09031781, 1.        ]])
